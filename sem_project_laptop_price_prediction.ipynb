# %% [markdown]
# # Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error
# !pip install catboost
import catboost
from catboost import CatBoostRegressor
# !pip3 install xgboost
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
# Out:
# Requirement already satisfied: catboost in c:\users\manideep\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: matplotlib in c:\users\manideep\anaconda3\lib\site-packages (from catboost) (3.5.2)
# Requirement already satisfied: scipy in c:\users\manideep\anaconda3\lib\site-packages (from catboost) (1.9.1)
# Requirement already satisfied: plotly in c:\users\manideep\anaconda3\lib\site-packages (from catboost) (5.9.0)
# Requirement already satisfied: six in c:\users\manideep\anaconda3\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: graphviz in c:\users\manideep\anaconda3\lib\site-packages (from catboost) (0.20.1)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\manideep\anaconda3\lib\site-packages (from catboost) (1.4.4)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\manideep\anaconda3\lib\site-packages (from catboost) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\manideep\anaconda3\lib\site-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\manideep\anaconda3\lib\site-packages (from pandas>=0.24.0->catboost) (2022.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\manideep\anaconda3\lib\site-packages (from matplotlib->catboost) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\manideep\anaconda3\lib\site-packages (from matplotlib->catboost) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\manideep\anaconda3\lib\site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\manideep\anaconda3\lib\site-packages (from matplotlib->catboost) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\manideep\anaconda3\lib\site-packages (from matplotlib->catboost) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\manideep\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\manideep\anaconda3\lib\site-packages (from plotly->catboost) (8.0.1)
# Requirement already satisfied: xgboost in c:\users\manideep\anaconda3\lib\site-packages (1.7.3)
# Requirement already satisfied: numpy in c:\users\manideep\anaconda3\lib\site-packages (from xgboost) (1.21.5)
# Requirement already satisfied: scipy in c:\users\manideep\anaconda3\lib\site-packages (from xgboost) (1.9.1)

# %% [markdown]
# # Loading the Data-Set for the Project

# %%
df = pd.read_csv('C:\\Users\\manideep\\Downloads\\laptop_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df.describe(include='all')
# Out:
#        Company  TypeName          Ram       Weight          Price  \
# count     1302      1302  1302.000000  1302.000000    1302.000000
# unique      19         6          NaN          NaN            NaN
# top       Dell  Notebook          NaN          NaN            NaN
# freq       297       727          NaN          NaN            NaN
# mean       NaN       NaN     8.385561     2.039415   59889.058673
# std        NaN       NaN     5.085166     0.665274   37251.183866
# min        NaN       NaN     2.000000     0.690000    9270.720000
# 25%        NaN       NaN     4.000000     1.500000   31914.720000
# 50%        NaN       NaN     8.000000     2.040000   52107.840000
# 75%        NaN       NaN     8.000000     2.300000   79303.816800
# max        NaN       NaN    64.000000     4.700000  324954.720000
#
#         Touchscreen         Ips          ppi      Cpu brand          HDD  \
# count   1302.000000  1302.00000  1302.000000           1302  1302.000000
# unique          NaN         NaN          NaN              5          NaN
# top             NaN         NaN          NaN  Intel Core i7          NaN
# freq            NaN         NaN          NaN            527          NaN
# mean       0.146697     0.27957   146.568497            NaN   414.101382
# std        0.353940     0.44896    43.069016            NaN   515.889348
# min        0.000000     0.00000    90.583402            NaN     0.000000
# 25%        0.000000     0.00000   127.335675            NaN     0.000000
# 50%        0.000000     0.00000   141.211998            NaN     0.000000
# 75%        0.000000     1.00000   157.350512            NaN  1000.000000
# max        1.000000     1.00000   352.465147            NaN  2000.000000
#
#                 SSD Gpu brand       os
# count   1302.000000      1302     1302
# unique          NaN         3        3
# top             NaN     Intel  Windows
# freq            NaN       722     1125
# mean     183.874040       NaN      NaN
# std      186.969314       NaN      NaN
# min        0.000000       NaN      NaN
# 25%        0.000000       NaN      NaN
# 50%      256.000000       NaN      NaN
# 75%      256.000000       NaN      NaN
# max     1024.000000       NaN      NaN

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %% [markdown]
# #  Checking for duplicated and null values in the data

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %% [markdown]
# #  Data Cleaning Process
# <ol>
#
# <li> Remove extra unnecessary details form Product Columns
#  <li> Extract CPU Vender, CPU Type and CPU Speed in Different Columns
#  <li> Convert Ram into Numeric Values
#  <li> Extract Memory type from Memory Column
#  <li> Convert Weight into numeric Values
#  <li> Extract GPU Vender, GPU Type in Different Columns
#  <li> Extract IPS and Touchscreen Feature form ScreenResolution Column
#  </ol>

# %% [markdown]
# #  Removing extra unnecessary Columns

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %% [markdown]
# # Convert Ram and Weight into numeric columns

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS   1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS   1.37   96095.8080

# %%
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: ScreenResolution, dtype: int64

# %% [markdown]
# #  Extract TouchScreen, Ips Type in Different Columns

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches  \
# 715   Lenovo            Notebook    14.0
# 684   Lenovo  2 in 1 Convertible    13.3
# 1174  Lenovo            Notebook    15.6
# 1152  Lenovo            Notebook    15.6
# 840     Asus              Gaming    17.3
#
#                                ScreenResolution                          Cpu  \
# 715                 IPS Panel Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 684   IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 8550U 1.8GHz
# 1174                          Full HD 1920x1080   Intel Core i7 7500U 2.7GHz
# 1152                          Full HD 1920x1080   Intel Core i5 6200U 2.3GHz
# 840                           Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz
#
#       Ram                Memory                      Gpu       OpSys  Weight  \
# 715     8             256GB SSD     Nvidia GeForce 920MX  Windows 10    1.87
# 684     8             512GB SSD   Intel UHD Graphics 620  Windows 10    1.19
# 1174    8               1TB HDD     Nvidia GeForce 940MX       No OS    2.20
# 1152    8               1TB HDD       AMD Radeon R5 M330       No OS    2.32
# 840    16  512GB SSD +  1TB HDD  Nvidia GeForce GTX 1060  Windows 10    2.73
#
#            Price  Touchscreen
# 715   45664.6896            0
# 684   79866.7200            1
# 1174  37775.5200            0
# 1152  31914.7200            0
# 840   95850.7200            0

# %%
df['Ips'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %% [markdown]
# # Extracting screen resolution in two different columns 'X_res', 'Y_res'

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.sample(5)
# Out:
#      Company  TypeName  Inches             ScreenResolution  \
# 1102    Acer  Notebook    15.6                     1366x768
# 1252  Lenovo  Notebook    15.6            Full HD 1920x1080
# 840     Asus    Gaming    17.3            Full HD 1920x1080
# 852     Dell  Notebook    17.3            Full HD 1920x1080
# 1000    Acer    Gaming    15.6  IPS Panel Full HD 1920x1080
#
#                                        Cpu  Ram                Memory  \
# 1102  Intel Celeron Dual Core 3205U 1.5GHz    4              16GB SSD
# 1252            Intel Core i3 6100U 2.3GHz    6             128GB SSD
# 840            Intel Core i7 6700HQ 2.6GHz   16  512GB SSD +  1TB HDD
# 852             Intel Core i7 7500U 2.7GHz    8               1TB HDD
# 1000           Intel Core i7 7700HQ 2.8GHz    8  128GB SSD +  1TB HDD
#
#                           Gpu       OpSys  Weight     Price  Touchscreen  Ips  \
# 1102        Intel HD Graphics   Chrome OS    2.20  11135.52            0    0
# 1252     Nvidia GeForce 920MX  Windows 10    2.40  30316.32            0    0
# 840   Nvidia GeForce GTX 1060  Windows 10    2.73  95850.72            0    0
# 852        AMD Radeon R7 M445       Linux    2.83  46087.20            0    0
# 1000  Nvidia GeForce GTX 1050  Windows 10    2.70  67132.80            0    1
#
#                        X_res Y_res
# 1102                    1366   768
# 1252            Full HD 1920  1080
# 840             Full HD 1920  1080
# 852             Full HD 1920  1080
# 1000  IPS Panel Full HD 1920  1080

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#   X_res Y_res
# 0  2560  1600
# 1  1440   900
# 2  1920  1080
# 3  2880  1800
# 4  2560  1600

# %% [markdown]
# # Converting X_res, Y_res into integer data type

# %%
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# memory usage: 132.5+ KB

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %% [markdown]
# # Creating a column 'ppi' by using the columns 'X_res', 'Y_res' and 'Inches'

# %%
df['ppi'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %% [markdown]
# # Deleting ScreenResolution column

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips  X_res  Y_res         ppi
# 0   71378.6832            0    1   2560   1600  226.983005
# 1   47895.5232            0    0   1440    900  127.677940
# 2   30636.0000            0    0   1920   1080  141.211998
# 3  135195.3360            0    1   2880   1800  220.534624
# 4   96095.8080            0    1   2560   1600  226.983005

# %% [markdown]
# # Deleting Inches, X_res, Y_res columns

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi
# 0  226.983005
# 1  127.677940
# 2  141.211998
# 3  220.534624
# 4  226.983005

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %% [markdown]
# # Extracting a column Cpu Name from Cpu

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi       Cpu Name
# 0  226.983005  Intel Core i5
# 1  127.677940  Intel Core i5
# 2  141.211998  Intel Core i5
# 3  220.534624  Intel Core i7
# 4  226.983005  Intel Core i5

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %% [markdown]
# # Extractiong a column Cpu brand from Cpu Name

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi       Cpu Name      Cpu brand
# 0  226.983005  Intel Core i5  Intel Core i5
# 1  127.677940  Intel Core i5  Intel Core i5
# 2  141.211998  Intel Core i5  Intel Core i5
# 3  220.534624  Intel Core i7  Intel Core i7
# 4  226.983005  Intel Core i5  Intel Core i5

# %% [markdown]
# # Deleting Cpu, Cpu Name columns

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  Ips         ppi      Cpu brand
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: Memory, dtype: int64

# %%
df["Memory"].unique
# Out:
# <bound method Series.unique of 0                 128GB SSD
# 1       128GB Flash Storage
# 2                 256GB SSD
# 3                 512GB SSD
# 4                 256GB SSD
#                ...
# 1298              128GB SSD
# 1299              512GB SSD
# 1300     64GB Flash Storage
# 1301                1TB HDD
# 1302              500GB HDD
# Name: Memory, Length: 1303, dtype: object>

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# C:\Users\manideep\AppData\Local\Temp\ipykernel_2588\2855148155.py:20: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D', '')
# C:\Users\manideep\AppData\Local\Temp\ipykernel_2588\2855148155.py:29: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D', '')

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight',
#        'Price', 'Touchscreen', 'Ips', 'ppi', 'Cpu brand', 'HDD', 'SSD',
#        'Hybrid', 'Flash_Storage'],
#       dtype='object')

# %%
df["Memory"]
# Out:
# 0                 128 SSD
# 1       128 Flash Storage
# 2                 256 SSD
# 3                 512 SSD
# 4                 256 SSD
#               ...
# 1298              128 SSD
# 1299              512 SSD
# 1300     64 Flash Storage
# 1301             1000 HDD
# 1302              500 HDD
# Name: Memory, Length: 1303, dtype: object

# %%
df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"]
# Out:
# 0                 128 SSD
# 1       128 Flash Storage
# 2                 256 SSD
# 3                 512 SSD
# 4                 256 SSD
#               ...
# 1298              128 SSD
# 1299              512 SSD
# 1300     64 Flash Storage
# 1301             1000 HDD
# 1302              500 HDD
# Name: Memory, Length: 1303, dtype: object

# %%
df.sample(5)
# Out:
#       Company            TypeName  Ram   Memory                    Gpu  \
# 82         HP            Notebook    8  256 SSD  Intel HD Graphics 620
# 656      Dell            Notebook    8  256 SSD         AMD Radeon 530
# 1224     Dell  2 in 1 Convertible    4  500 HDD  Intel HD Graphics 620
# 1021  Toshiba           Ultrabook    8  256 SSD  Intel HD Graphics 520
# 1206       HP            Notebook    8  256 SSD  Intel HD Graphics 620
#
#            OpSys  Weight     Price  Touchscreen  Ips         ppi  \
# 82    Windows 10    1.63  45820.80            0    0  157.350512
# 656   Windows 10    2.20  48964.32            0    0  141.211998
# 1224  Windows 10    2.08  27119.52            1    0  146.860478
# 1021  Windows 10    1.20  84715.20            0    0  165.632118
# 1206  Windows 10    1.91  30849.12            0    0  100.454670
#
#           Cpu brand  HDD  SSD  Hybrid  Flash_Storage
# 82    Intel Core i5    0  256       0              0
# 656   Intel Core i7    0  256       0              0
# 1224  Intel Core i3  500    0       0              0
# 1021  Intel Core i5    0  256       0              0
# 1206  Intel Core i5    0  256       0              0

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD  Hybrid  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128       0
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0       0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256       0
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512       0
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256       0
#
#    Flash_Storage
# 0              0
# 1            128
# 2              0
# 3              0
# 4              0

# %%
df.corr()['Price']
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# Ips              0.252208
# ppi              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256
#
#   Gpu brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu brand, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu brand, dtype: int64

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu brand  HDD  SSD Gpu brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  Ips         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        Cpu brand  HDD  SSD Gpu brand                  os
# 0  Intel Core i5    0  128     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7    0  512       AMD                 Mac
# 4  Intel Core i5    0  256     Intel                 Mac

# %%
df.corr()['Price']
# Out:
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# Ips            0.253320
# ppi            0.475368
# HDD           -0.096891
# SSD            0.670660
# Name: Price, dtype: float64

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\manideep\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Touchscreen', ylabel='Price'>

# %%
df['Ips'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Ips'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Ips', ylabel='Price'>

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# C:\Users\manideep\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Price'>

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Ram', 'Weight', 'Price', 'Touchscreen', 'Ips',
#        'ppi', 'Cpu brand', 'HDD', 'SSD', 'Gpu brand', 'os'],
#       dtype='object')

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
#                   Cpu brand   HDD  SSD Gpu brand                  os
# 0             Intel Core i5     0  128     Intel                 Mac
# 1             Intel Core i5     0    0     Intel                 Mac
# 2             Intel Core i5     0  256     Intel  Others/No OS/Linux
# 3             Intel Core i7     0  512       AMD                 Mac
# 4             Intel Core i5     0  256     Intel                 Mac
# ...                     ...   ...  ...       ...                 ...
# 1298          Intel Core i7     0  128     Intel             Windows
# 1299          Intel Core i7     0  512     Intel             Windows
# 1300  Other Intel Processor     0    0     Intel             Windows
# 1301          Intel Core i7  1000    0       AMD             Windows
# 1302  Other Intel Processor   500    0     Intel             Windows
#
# [1302 rows x 12 columns]

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 1141      MSI              Gaming    8    2.40            0    0  141.211998
# 1049     Asus             Netbook    4    1.20            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211998
# 878      Dell            Notebook    4    2.18            0    0  141.211998
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0  100.454670
# 299      Asus           Ultrabook   16    1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.20            0    0  100.454670
# 527    Lenovo            Notebook    8    2.20            0    0  100.454670
# 1193    Apple           Ultrabook    8    0.92            0    1  226.415547
#
#                   Cpu brand   HDD  SSD Gpu brand                  os
# 183           Intel Core i5     0  128     Intel             Windows
# 1141          Intel Core i7  1000  128    Nvidia             Windows
# 1049  Other Intel Processor     0    0     Intel  Others/No OS/Linux
# 1020          Intel Core i3  1000    0     Intel             Windows
# 878           Intel Core i5  1000  128    Nvidia             Windows
# ...                     ...   ...  ...       ...                 ...
# 466           Intel Core i3   500    0    Nvidia             Windows
# 299           Intel Core i7     0  512    Nvidia             Windows
# 493           AMD Processor  1000    0       AMD             Windows
# 527           Intel Core i3  2000    0    Nvidia  Others/No OS/Linux
# 1193  Other Intel Processor     0    0     Intel                 Mac
#
# [1106 rows x 12 columns]

# %%
X_test
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 248       HP            Notebook    4    1.49            0    1  165.632118
# 555     Asus            Notebook    4    2.00            0    0  100.454670
# 1251      HP            Notebook    4    1.86            0    0  100.454670
# 547   Lenovo            Notebook    4    2.15            0    0  141.211998
# 885       HP  2 in 1 Convertible    4    1.28            1    0  165.632118
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1129      HP              Gaming    8    3.35            0    1  127.335675
# 172   Lenovo            Notebook    4    2.20            0    0  100.454670
# 322     Asus            Notebook    8    2.00            0    0  157.350512
# 996       HP           Ultrabook    8    1.11            1    1  165.632118
# 470       HP  2 in 1 Convertible    8    1.29            1    1  331.264236
#
#                   Cpu brand   HDD  SSD Gpu brand                  os
# 248           Intel Core i5   500    0     Intel             Windows
# 555   Other Intel Processor   500    0     Intel  Others/No OS/Linux
# 1251          AMD Processor   500    0       AMD             Windows
# 547           Intel Core i5  1000    0     Intel  Others/No OS/Linux
# 885           Intel Core i5     0  256     Intel             Windows
# ...                     ...   ...  ...       ...                 ...
# 1129          Intel Core i5  1000  128    Nvidia             Windows
# 172           AMD Processor   500    0       AMD  Others/No OS/Linux
# 322           Intel Core i7     0  256     Intel             Windows
# 996           Intel Core i7     0  256     Intel             Windows
# 470           Intel Core i7     0  512     Intel             Windows
#
# [196 rows x 12 columns]

# %% [markdown]
# ### Linear regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8073277448418712
# MAE 0.2101782797642822

# %% [markdown]
# ### Ridge Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.81273310313118
# MAE 0.20926802242583054

# %% [markdown]
# ### Lasso Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8071853945317105
# MAE 0.21114361613472565

# %% [markdown]
# ### KNN

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8021984604448553
# MAE 0.19319716721521116

# %% [markdown]
# ### Decision Tree

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8399300080472472
# MAE 0.1831047991664511

# %% [markdown]
# ### SVM

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.808318090228966
# MAE 0.20239059427193437

# %% [markdown]
# ### Random Forest

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8873402378382488
# MAE 0.15860130110457718

# %% [markdown]
# ### AdaBoost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7875223917705826
# MAE 0.23834332394534602

# %% [markdown]
# ### Gradient Boost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8809219791114276
# MAE 0.15969923708207465

# %% [markdown]
# ### XgBoost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 
# 382:	learn: 0.1820032	total: 1s	remaining: 1.62s
# 383:	learn: 0.1818777	total: 1.01s	remaining: 1.61s
# 384:	learn: 0.1818325	total: 1.01s	remaining: 1.61s
# 385:	learn: 0.1816656	total: 1.01s	remaining: 1.61s
# 386:	learn: 0.1816523	total: 1.01s	remaining: 1.6s
# 387:	learn: 0.1814761	total: 1.02s	remaining: 1.6s
# 388:	learn: 0.1812933	total: 1.02s	remaining: 1.6s
# 389:	learn: 0.1811608	total: 1.02s	remaining: 1.6s
# 390:	learn: 0.1809745	total: 1.02s	remaining: 1.59s
# 391:	learn: 0.1809625	total: 1.03s	remaining: 1.59s
# 392:	learn: 0.1809213	total: 1.03s	remaining: 1.59s
# 393:	learn: 0.1807459	total: 1.03s	remaining: 1.59s
# 394:	learn: 0.1806310	total: 1.03s	remaining: 1.58s
# 395:	learn: 0.1804599	total: 1.04s	remaining: 1.58s
# 396:	learn: 0.1804429	total: 1.04s	remaining: 1.58s
# 397:	learn: 0.1803450	total: 1.04s	remaining: 1.57s
# 398:	learn: 0.1803332	total: 1.04s	remaining: 1.57s
# 399:	learn: 0.1801668	total: 1.05s	remaining: 1.57s
# 400:	learn: 0.1800719	total: 1.05s	remaining: 1.57s
# 401:	learn: 0.1799237	total: 1.05s	remaining: 1.56s
# 402:	learn: 0.1797371	total: 1.05s	remaining: 1.56s
# 403:	learn: 0.1795643	total: 1.06s	remaining: 1.56s
# 404:	learn: 0.1795056	total: 1.06s	remaining: 1.55s
# 405:	learn: 0.1794248	total: 1.06s	remaining: 1.55s
# 406:	learn: 0.1794089	total: 1.06s	remaining: 1.55s
# 407:	learn: 0.1791036	total: 1.07s	remaining: 1.55s
# 408:	learn: 0.1790651	total: 1.07s	remaining: 1.54s
# 409:	learn: 0.1789047	total: 1.07s	remaining: 1.54s
# 410:	learn: 0.1787133	total: 1.07s	remaining: 1.54s
# 411:	learn: 0.1784889	total: 1.07s	remaining: 1.53s
# 412:	learn: 0.1784089	total: 1.08s	remaining: 1.53s
# 413:	learn: 0.1781857	total: 1.08s	remaining: 1.53s
# 414:	learn: 0.1781718	total: 1.08s	remaining: 1.53s
# 415:	learn: 0.1781609	total: 1.08s	remaining: 1.52s
# 416:	learn: 0.1778801	total: 1.09s	remaining: 1.52s
# 417:	learn: 0.1778684	total: 1.09s	remaining: 1.52s
# 418:	learn: 0.1778594	total: 1.09s	remaining: 1.51s
# 419:	learn: 0.1778483	total: 1.09s	remaining: 1.51s
# 420:	learn: 0.1776347	total: 1.1s	remaining: 1.51s
# 421:	learn: 0.1774001	total: 1.1s	remaining: 1.51s
# 422:	learn: 0.1771610	total: 1.1s	remaining: 1.5s
# 423:	learn: 0.1769540	total: 1.11s	remaining: 1.5s
# 424:	learn: 0.1767404	total: 1.11s	remaining: 1.5s
# 425:	learn: 0.1767254	total: 1.11s	remaining: 1.5s
# 426:	learn: 0.1767148	total: 1.11s	remaining: 1.49s
# 427:	learn: 0.1765181	total: 1.12s	remaining: 1.49s
# 428:	learn: 0.1763889	total: 1.12s	remaining: 1.49s
# 475:	learn: 0.1705078	total: 1.24s	remaining: 1.36s
# 476:	learn: 0.1702842	total: 1.24s	remaining: 1.36s
# 477:	learn: 0.1701269	total: 1.25s	remaining: 1.36s
# 478:	learn: 0.1700221	total: 1.25s	remaining: 1.36s
# 479:	learn: 0.1700129	total: 1.25s	remaining: 1.35s
# 480:	learn: 0.1698101	total: 1.25s	remaining: 1.35s
# 481:	learn: 0.1697995	total: 1.25s	remaining: 1.35s
# 482:	learn: 0.1696907	total: 1.26s	remaining: 1.35s
# 483:	learn: 0.1696634	total: 1.26s	remaining: 1.34s
# 484:	learn: 0.1695576	total: 1.26s	remaining: 1.34s
# 485:	learn: 0.1694330	total: 1.26s	remaining: 1.34s
# 486:	learn: 0.1692692	total: 1.27s	remaining: 1.33s
# 487:	learn: 0.1689795	total: 1.27s	remaining: 1.33s
# 488:	learn: 0.1688824	total: 1.27s	remaining: 1.33s
# 489:	learn: 0.1688649	total: 1.27s	remaining: 1.33s
# 490:	learn: 0.1688205	total: 1.28s	remaining: 1.32s
# 491:	learn: 0.1688138	total: 1.28s	remaining: 1.32s
# 492:	learn: 0.1687112	total: 1.28s	remaining: 1.32s
# 493:	learn: 0.1686281	total: 1.28s	remaining: 1.31s
# 494:	learn: 0.1685081	total: 1.29s	remaining: 1.31s
# 495:	learn: 0.1684492	total: 1.29s	remaining: 1.31s
# 496:	learn: 0.1682761	total: 1.29s	remaining: 1.31s
# 497:	learn: 0.1680956	total: 1.29s	remaining: 1.3s
# 498:	learn: 0.1680161	total: 1.3s	remaining: 1.3s
# 499:	learn: 0.1679740	total: 1.3s	remaining: 1.3s
# 500:	learn: 0.1679656	total: 1.3s	remaining: 1.3s
# 501:	learn: 0.1679572	total: 1.3s	remaining: 1.29s
# 502:	learn: 0.1678744	total: 1.31s	remaining: 1.29s
# 503:	learn: 0.1678657	total: 1.31s	remaining: 1.29s
# 504:	learn: 0.1678262	total: 1.31s	remaining: 1.28s
# 505:	learn: 0.1677233	total: 1.31s	remaining: 1.28s
# 506:	learn: 0.1676281	total: 1.32s	remaining: 1.28s
# 507:	learn: 0.1676176	total: 1.32s	remaining: 1.28s
# 508:	learn: 0.1674660	total: 1.32s	remaining: 1.28s
# 509:	learn: 0.1674289	total: 1.33s	remaining: 1.27s
# 510:	learn: 0.1674219	total: 1.33s	remaining: 1.27s
# 511:	learn: 0.1673642	total: 1.33s	remaining: 1.27s
# 512:	learn: 0.1672826	total: 1.33s	remaining: 1.27s
# 513:	learn: 0.1672752	total: 1.34s	remaining: 1.26s
# 514:	learn: 0.1671542	total: 1.34s	remaining: 1.26s
# 515:	learn: 0.1670129	total: 1.34s	remaining: 1.26s
# 516:	learn: 0.1670044	total: 1.34s	remaining: 1.26s
# 517:	learn: 0.1669346	total: 1.35s	remaining: 1.25s
# 518:	learn: 0.1667827	total: 1.35s	remaining: 1.25s
# 519:	learn: 0.1666297	total: 1.35s	remaining: 1.25s
# 520:	learn: 0.1664837	total: 1.36s	remaining: 1.25s
# 521:	learn: 0.1663447	total: 1.36s	remaining: 1.24s
# 522:	learn: 0.1662347	total: 1.36s	remaining: 1.24s
# 523:	learn: 0.1660839	total: 1.36s	remaining: 1.24s
# 524:	learn: 0.1658611	total: 1.37s	remaining: 1.24s
# 525:	learn: 0.1656610	total: 1.37s	remaining: 1.23s
# 526:	learn: 0.1656541	total: 1.37s	remaining: 1.23s
# 527:	learn: 0.1656477	total: 1.37s	remaining: 1.23s
# 528:	learn: 0.1656300	total: 1.38s	remaining: 1.23s
# 529:	learn: 0.1656047	total: 1.38s	remaining: 1.22s
# 530:	learn: 0.1655293	total: 1.38s	remaining: 1.22s
# 531:	learn: 0.1655235	total: 1.38s	remaining: 1.22s
# 532:	learn: 0.1653790	total: 1.39s	remaining: 1.22s
# 533:	learn: 0.1652668	total: 1.39s	remaining: 1.21s
# 534:	learn: 0.1652425	total: 1.39s	remaining: 1.21s
# 535:	learn: 0.1650273	total: 1.39s	remaining: 1.21s
# 536:	learn: 0.1650192	total: 1.4s	remaining: 1.2s
# 537:	learn: 0.1648564	total: 1.4s	remaining: 1.2s
# 538:	learn: 0.1647523	total: 1.4s	remaining: 1.2s
# 539:	learn: 0.1646409	total: 1.4s	remaining: 1.2s
# 540:	learn: 0.1646345	total: 1.41s	remaining: 1.19s
# 541:	learn: 0.1644296	total: 1.41s	remaining: 1.19s
# 542:	learn: 0.1643386	total: 1.41s	remaining: 1.19s
# 543:	learn: 0.1643318	total: 1.42s	remaining: 1.19s
# 544:	learn: 0.1641639	total: 1.42s	remaining: 1.18s
# 545:	learn: 0.1641555	total: 1.42s	remaining: 1.18s
# 546:	learn: 0.1640061	total: 1.42s	remaining: 1.18s
# 547:	learn: 0.1637787	total: 1.43s	remaining: 1.18s
# 548:	learn: 0.1637620	total: 1.43s	remaining: 1.17s
# 549:	learn: 0.1636139	total: 1.43s	remaining: 1.17s
# 550:	learn: 0.1636049	total: 1.43s	remaining: 1.17s
# 551:	learn: 0.1634241	total: 1.44s	remaining: 1.17s
# 552:	learn: 0.1632863	total: 1.44s	remaining: 1.16s
# 553:	learn: 0.1631764	total: 1.44s	remaining: 1.16s
# 554:	learn: 0.1631322	total: 1.44s	remaining: 1.16s
# 555:	learn: 0.1629777	total: 1.45s	remaining: 1.15s
# 556:	learn: 0.1628830	total: 1.45s	remaining: 1.15s
# 557:	learn: 0.1628763	total: 1.45s	remaining: 1.15s
# 558:	learn: 0.1628705	total: 1.45s	remaining: 1.15s
# 559:	learn: 0.1627773	total: 1.46s	remaining: 1.14s
# 560:	learn: 0.1627710	total: 1.46s	remaining: 1.14s
# 561:	learn: 0.1625849	total: 1.46s	remaining: 1.14s
# 562:	learn: 0.1624160	total: 1.46s	remaining: 1.14s
# 563:	learn: 0.1623314	total: 1.47s	remaining: 1.13s
# 564:	learn: 0.1623267	total: 1.47s	remaining: 1.13s
# 565:	learn: 0.1621867	total: 1.47s	remaining: 1.13s
# 566:	learn: 0.1621054	total: 1.47s	remaining: 1.13s
# 567:	learn: 0.1619357	total: 1.48s	remaining: 1.12s
# 568:	learn: 0.1617821	total: 1.48s	remaining: 1.12s
